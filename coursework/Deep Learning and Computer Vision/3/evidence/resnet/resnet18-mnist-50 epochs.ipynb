# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import time
import torch
from sklearn.metrics import confusion_matrix
import seaborn as sns
import torchvision
import numpy as np

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
batch_size = 32

trans = [torchvision.transforms.ToTensor()]
# trans.insert(0, torchvision.transforms.Resize((224, 224)))
trans = torchvision.transforms.Compose(trans)

train_dataset = torchvision.datasets.MNIST(root="data", train=True, transform=trans, download=True)
test_dataset = torchvision.datasets.MNIST(root="data", train=False, transform=trans, download=True)

train_iter, test_iter = (torch.utils.data.DataLoader(train_dataset, batch_size, shuffle=True, num_workers=2, pin_memory=True), # Using pinned memory
        torch.utils.data.DataLoader(test_dataset, batch_size, shuffle=False, num_workers=2, pin_memory=True)) # Using pinned memory

# %% [markdown]
# # Model

# %%
class BasicBlock(torch.nn.Module):
    def __init__(self, input_channels, output_channels, stride=1):
        super(BasicBlock, self).__init__()

        self.conv1 = torch.nn.Conv2d(input_channels, output_channels, kernel_size=3, padding=1, stride=stride)
        self.bn1 = torch.nn.BatchNorm2d(output_channels)
        self.relu1 = torch.nn.ReLU()

        self.conv2 = torch.nn.Conv2d(output_channels, output_channels, kernel_size=3, padding=1)
        self.bn2 = torch.nn.BatchNorm2d(output_channels)

        self.conv3 = None
        if (input_channels != output_channels) or (stride != 1):
            self.conv3 = torch.nn.Conv2d(input_channels, output_channels, kernel_size=1, stride=stride)

        self.relu2 = torch.nn.ReLU()

    def forward(self, x):
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu1(out)

        out = self.conv2(out)
        out = self.bn2(out)

        if self.conv3:
            out += self.conv3(x)
        else:
            out += x

        return self.relu2(out)

# %%
class ResNetMacroblock(torch.nn.Module):
    def __init__(self, input_channels, first_macroblock=False):
        super(ResNetMacroblock, self).__init__()

        s = 1 if first_macroblock else 2

        self.rb1 = BasicBlock(input_channels, input_channels * s, stride=s)
        self.rb2 = BasicBlock(input_channels * s, input_channels * s, stride=1)

    def forward(self, x):
        out = self.rb1(x)
        out = self.rb2(out)
        return out

# %%
class ResNet18(torch.nn.Module):
    def __init__(self, num_outputs):
        super(ResNet18, self).__init__()

        self.num_outputs = num_outputs

        self.conv = torch.nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3) # Assuming 1 x 224 x 224 input images
        self.bn = torch.nn.BatchNorm2d(64) 
        self.relu = torch.nn.ReLU()
        self.maxpool = torch.nn.MaxPool2d(kernel_size=3, stride=2, padding=1)

        self.rmb1 = ResNetMacroblock(64, first_macroblock=True)
        self.rmb2 = ResNetMacroblock(64)
        self.rmb3 = ResNetMacroblock(128)
        self.rmb4 = ResNetMacroblock(256)

        self.channel_avg = torch.nn.AdaptiveAvgPool2d((1, 1))
        self.flatten = torch.nn.Flatten()
        self.linear = torch.nn.Linear(512, self.num_outputs)

    def forward(self, x):
        out = self.conv(x)
        out = self.bn(out)
        out = self.relu(out)
        out = self.maxpool(out)

        out = self.rmb1(out)
        out = self.rmb2(out)
        out = self.rmb3(out)
        out = self.rmb4(out)

        out = self.channel_avg(out)
        out = self.flatten(out)
        out = self.linear(out)

        return out

# %%
# Applies Xavier initialization if the `torch.nn.Module` is `torch.nn.Linear` or `torch.nn.Conv2d`
def init_weights(m):
    if type(m) == torch.nn.Linear or type(m) == torch.nn.Conv2d:
        torch.nn.init.xavier_uniform_(m.weight)

num_outputs = 10

model = ResNet18(10).to(device) # Creates and moves the model to `device`
model.apply(init_weights) # Applies `init_weights` to every `torch.nn.Module` inside `model`
# Out:
# ResNet18(
#   (conv): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU()
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (rmb1): ResNetMacroblock(
#     (rb1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU()
#     )
#     (rb2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU()
#     )
#   )
#   (rmb2): ResNetMacroblock(
#     (rb1): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2))
#       (relu2): ReLU()
#     )
#     (rb2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU()
#     )
#   )
#   (rmb3): ResNetMacroblock(
#     (rb1): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2))
#       (relu2): ReLU()
#     )
#     (rb2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU()
#     )
#   )
#   (rmb4): ResNetMacroblock(
#     (rb1): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2))
#       (relu2): ReLU()
#     )
#     (rb2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU()
#     )
#   )
#   (channel_avg): AdaptiveAvgPool2d(output_size=(1, 1))
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
def correct(logits, y):
    y_hat = logits.argmax(axis=1) # Finds the column with the highest value for each row of `logits`.
    return (y_hat == y).float().sum() # Computes the number of times that `y_hat` and `y` match.

def evaluate_metric(model, data_iter, metric):
    """Compute the average `metric` of the model on a dataset."""
    c = 0.
    n = 0.
    for X, y in data_iter:
        X, y = X.to(device), y.to(device)
        logits = model(X)
        c += metric(logits, y)
        n += len(y)

    return float(c / n) * 100

# %% [markdown]
# # Visualisation of model training & testing processes

# %%
criterion = torch.nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters())
# optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

losses = [] # Stores the loss for each training batch
train_accs = [] # Stores the training accuracy after each epoch
test_accs = [] # Stores the testing accuracy after each epoch

num_epochs = 50
for epoch in range(num_epochs):
    total_loss=0
    correct_cnt=0
    
    print(f'\nEpoch {epoch + 1}/{num_epochs}.')
    start_time = time.perf_counter()
    
    model.train()
    
    for images, labels in train_iter:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        predict = model(images)
        l = criterion(predict, labels)
        l.backward()
        optimizer.step()
        total_loss += l.item() *images.shape[0]

    loss = round(total_loss / len(train_iter.dataset), 4)
    losses.append(loss)

    
    with torch.no_grad(): # Computing performance metrics does not require gradients
        model.eval()
        train_accs.append(evaluate_metric(model, train_iter, correct))
        test_accs.append(evaluate_metric(model, test_iter, correct)) #compute accuracy in the testing dataset

        end_time = time.perf_counter()
        print(f'Loss:{loss} Training accuracy: {train_accs[-1]:.2f}%. Testing accuracy: {test_accs[-1]:.2f}%. Duration: {end_time - start_time:.3f}s.') # Computes and displays training/testing dataset accuracy.



plt.plot(losses) # Plots the loss for each training batch
plt.xlabel('Training batch')
plt.ylabel('Cross entropy loss')
plt.show()


plt.plot(train_accs, label='Training accuracy')
plt.plot(test_accs, label='Testing accuracy')
plt.legend(loc='best')
plt.xlabel('Epoch')
plt.show()
# Out:
# Epoch 1/50.
# /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
#   return F.conv2d(input, weight, bias, self.stride,
# Loss:0.1678 Training accuracy: 98.52%. Testing accuracy: 98.36%. Duration: 26.837s.
#
# Epoch 2/50.
# Loss:0.0755 Training accuracy: 98.79%. Testing accuracy: 98.89%. Duration: 25.887s.
#
# Epoch 3/50.
# Loss:0.0573 Training accuracy: 99.04%. Testing accuracy: 98.92%. Duration: 25.771s.
#
# Epoch 4/50.
# Loss:0.0516 Training accuracy: 99.32%. Testing accuracy: 99.04%. Duration: 24.628s.
#
# Epoch 5/50.
# Loss:0.0367 Training accuracy: 99.27%. Testing accuracy: 98.90%. Duration: 24.387s.
#
# Epoch 6/50.
# Loss:0.0361 Training accuracy: 98.78%. Testing accuracy: 98.38%. Duration: 24.883s.
#
# Epoch 7/50.
# Loss:0.0299 Training accuracy: 98.55%. Testing accuracy: 98.41%. Duration: 24.472s.
#
# Epoch 8/50.
# Loss:0.0267 Training accuracy: 99.40%. Testing accuracy: 99.05%. Duration: 24.906s.
#
# Epoch 9/50.
# Loss:0.0213 Training accuracy: 99.73%. Testing accuracy: 99.39%. Duration: 24.401s.
#
# Epoch 10/50.
# Loss:0.0206 Training accuracy: 99.60%. Testing accuracy: 99.14%. Duration: 24.178s.
#
# Epoch 11/50.
# Loss:0.0178 Training accuracy: 99.58%. Testing accuracy: 99.09%. Duration: 24.783s.
#
# Epoch 12/50.
# Loss:0.0177 Training accuracy: 99.76%. Testing accuracy: 99.30%. Duration: 25.605s.
#
# Epoch 13/50.
# Loss:0.0169 Training accuracy: 99.48%. Testing accuracy: 98.89%. Duration: 24.977s.
#
# Epoch 14/50.
# Loss:0.013 Training accuracy: 99.80%. Testing accuracy: 99.34%. Duration: 25.789s.
#
# Epoch 15/50.
# Loss:0.0132 Training accuracy: 99.69%. Testing accuracy: 99.02%. Duration: 25.201s.
#
# Epoch 16/50.
# Loss:0.0113 Training accuracy: 99.66%. Testing accuracy: 99.08%. Duration: 25.632s.
#
# Epoch 17/50.
# Loss:0.0114 Training accuracy: 99.83%. Testing accuracy: 99.37%. Duration: 25.432s.
#
# Epoch 18/50.
# Loss:0.0102 Training accuracy: 99.90%. Testing accuracy: 99.25%. Duration: 25.469s.
#
# Epoch 19/50.
# Loss:0.0112 Training accuracy: 99.91%. Testing accuracy: 99.39%. Duration: 25.975s.
#
# Epoch 20/50.
# Loss:0.0088 Training accuracy: 99.86%. Testing accuracy: 99.24%. Duration: 25.723s.
#
# Epoch 21/50.
# Loss:0.0082 Training accuracy: 99.85%. Testing accuracy: 99.37%. Duration: 24.986s.
#
# Epoch 22/50.
# Loss:0.0107 Training accuracy: 99.92%. Testing accuracy: 99.35%. Duration: 24.310s.
#
# Epoch 23/50.
# Loss:0.0074 Training accuracy: 99.90%. Testing accuracy: 99.35%. Duration: 24.481s.
#
# Epoch 24/50.
# Loss:0.0065 Training accuracy: 99.58%. Testing accuracy: 98.94%. Duration: 24.587s.
#
# Epoch 25/50.
# Loss:0.0062 Training accuracy: 99.94%. Testing accuracy: 99.33%. Duration: 24.394s.
#
# Epoch 26/50.
# Loss:0.0075 Training accuracy: 99.88%. Testing accuracy: 99.31%. Duration: 25.737s.
#
# Epoch 27/50.
# Loss:0.0067 Training accuracy: 99.33%. Testing accuracy: 98.72%. Duration: 25.620s.
#
# Epoch 28/50.
# Loss:0.0055 Training accuracy: 99.83%. Testing accuracy: 99.27%. Duration: 25.795s.
#
# Epoch 29/50.
# Loss:0.0077 Training accuracy: 99.93%. Testing accuracy: 99.44%. Duration: 25.941s.
#
# Epoch 30/50.
# Loss:0.0055 Training accuracy: 99.86%. Testing accuracy: 99.20%. Duration: 25.636s.
#
# Epoch 31/50.
# Loss:0.006 Training accuracy: 99.87%. Testing accuracy: 99.34%. Duration: 25.525s.
#
# Epoch 32/50.
# Loss:0.0072 Training accuracy: 99.92%. Testing accuracy: 99.39%. Duration: 24.712s.
#
# Epoch 33/50.
# Loss:0.0048 Training accuracy: 99.93%. Testing accuracy: 99.27%. Duration: 25.433s.
#
# Epoch 34/50.
# Loss:0.0052 Training accuracy: 99.93%. Testing accuracy: 99.29%. Duration: 24.882s.
#
# Epoch 35/50.
# Loss:0.0054 Training accuracy: 99.97%. Testing accuracy: 99.38%. Duration: 24.668s.
#
# Epoch 36/50.
# Loss:0.0041 Training accuracy: 99.94%. Testing accuracy: 99.29%. Duration: 24.794s.
#
# Epoch 37/50.
# Loss:0.0065 Training accuracy: 99.86%. Testing accuracy: 99.39%. Duration: 25.121s.
#
# Epoch 38/50.
# Loss:0.006 Training accuracy: 99.98%. Testing accuracy: 99.36%. Duration: 24.384s.
#
# Epoch 39/50.
# Loss:0.004 Training accuracy: 99.96%. Testing accuracy: 99.38%. Duration: 26.061s.
#
# Epoch 40/50.
# Loss:0.0047 Training accuracy: 99.96%. Testing accuracy: 99.34%. Duration: 25.901s.
#
# Epoch 41/50.
# Loss:0.0055 Training accuracy: 99.94%. Testing accuracy: 99.37%. Duration: 25.775s.
#
# Epoch 42/50.
# Loss:0.004 Training accuracy: 99.96%. Testing accuracy: 99.37%. Duration: 25.508s.
#
# Epoch 43/50.
# Loss:0.0061 Training accuracy: 99.94%. Testing accuracy: 99.40%. Duration: 25.586s.
#
# Epoch 44/50.
# Loss:0.0034 Training accuracy: 99.96%. Testing accuracy: 99.34%. Duration: 25.442s.
#
# Epoch 45/50.
# Loss:0.0028 Training accuracy: 99.92%. Testing accuracy: 99.21%. Duration: 25.706s.
#
# Epoch 46/50.
# Loss:0.0045 Training accuracy: 99.95%. Testing accuracy: 99.40%. Duration: 25.812s.
#
# Epoch 47/50.
# Loss:0.003 Training accuracy: 99.98%. Testing accuracy: 99.30%. Duration: 25.290s.
#
# Epoch 48/50.
# Loss:0.0045 Training accuracy: 99.94%. Testing accuracy: 99.28%. Duration: 26.002s.
#
# Epoch 49/50.
# Loss:0.0036 Training accuracy: 99.97%. Testing accuracy: 99.43%. Duration: 26.241s.
#
# Epoch 50/50.
# Loss:0.004 Training accuracy: 99.97%. Testing accuracy: 99.33%. Duration: 25.845s.

# %% [markdown]
# # confusion matrix

# %%
classes = train_dataset.classes
all_preds = []
all_labels = []

with torch.no_grad():
    model.eval()
    for images, labels in test_iter:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
        
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
def imshow(images, labels, predicted):
    fig, axs = plt.subplots(1, len(images), figsize=(15, 3))
    for i, (img, label, pred) in enumerate(zip(images, labels, predicted)):
        img = img / 2 + 0.5
        npimg = img.cpu().numpy()
        axs[i].imshow(np.transpose(npimg, (1, 2, 0)))
        axs[i].set_title(f'True: {classes[label]}\nPredicted: {classes[pred]}')
        axs[i].axis('off')
    plt.show()

correct_images, correct_labels, correct_predicted = [], [], []
incorrect_images, incorrect_labels, incorrect_predicted = [], [], []

with torch.no_grad():
    model.eval()
    for images, labels in test_iter:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        
        for img, label, pred in zip(images, labels, predicted):
            if pred == label and len(correct_images) < 5:
                correct_images.append(img)
                correct_labels.append(label.item())
                correct_predicted.append(pred.item())
            elif pred != label and len(incorrect_images) < 5:
                incorrect_images.append(img)
                incorrect_labels.append(label.item())
                incorrect_predicted.append(pred.item())
            if len(correct_images) >= 5 and len(incorrect_images) >= 5:
                break
        if len(correct_images) >= 5 and len(incorrect_images) >= 5:
            break

# %% [markdown]
# # Image examples of success cases

# %%
print('Correctly Classified Images')

if len(correct_images) >= 5:
    imshow(correct_images, correct_labels, correct_predicted)
# Out:
# Correctly Classified Images

# %% [markdown]
# # Image examples of failure cases

# %%
print("Incorrectly Classified Images")

if len(incorrect_images) >= 5:
    imshow(incorrect_images, incorrect_labels, incorrect_predicted)
# Out:
# Incorrectly Classified Images
